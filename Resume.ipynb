# %% [markdown]
# # JAGADEESH VUNGARALA
#
# `Fresher`
#
# <img src="https://tinypic.host/images/2023/08/07/IMG_20230601_190145.jpeg" alt="IMG_20230601_190145.jpeg" border="0" width="150" height= "100">
#
# `jagadeeshvungarala@gmail.com`
#
# `Ongole`
#
# Linkedin:-<i><b>https://www.linkedin.com/in/jagadish-vungarala-57b508234/</b></i>
#
# # EDUCATION
#
# - B.Tech
#    - Pace Institute Of Technology And Science's
#    - Courses
#        - Computer Science Engineering
#        - GPA-7.34
#        - 08/2019 to 04/2023
#
# - 12Th Standard
#     - Narayana Junior College
#     - Courses
#       - MPC
#       - 03/2017 to 03/2019
#       - GPA-8.1
#
# - 10Th Standard
#     - V.N.G High School
#     - 06/2016 to 04/2017
#     - GPA-7.7
#
# # SKILLS
#
# `Python,Html,dbms`
#
# # PERSONAL PROJECTS
#
# 1. Web Scraping With Python
#     - In this article on Web Scraping with python you will learn about web scraping in brief and see how to extract data from website with a demonstration.
# 2. Remote Android Contacts And Messages Access
#     - Remote android Contacts and message access is an application built on the android platform, which helps you to retrieve the contacts or the message stored on your remote android mobile.
#
# ## HOBBIES
# `Music,Badminton`
